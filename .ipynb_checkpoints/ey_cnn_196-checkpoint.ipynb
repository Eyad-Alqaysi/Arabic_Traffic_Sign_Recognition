# %% [markdown]
# # Traffic sign recognition

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import transforms, datasets
import timm
from sklearn.metrics import f1_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Data Agumention

# %%
transform = transforms.Compose([
    transforms.Resize((224, 224)), 
    transforms.RandomRotation(20), 
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.ToTensor(),
])

# %%
# Load your data
train_dataset = datasets.ImageFolder(root='../../main_dataset/train', transform=transform)
val_dataset = datasets.ImageFolder(root='../../main_dataset/val', transform=transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# %% [markdown]
# # Model Architecture

# %%
# Load pre-trained MobileNet model
model = timm.create_model('mobilevitv2_075.cvnets_in1k', pretrained=True)
num_classes = len(train_dataset.classes)

# Replace the classifier layer
model.head.fc = nn.Linear(model.head.fc.in_features, num_classes)

# Check if CUDA is available and get the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)
print(model)
# Out:
# ByobNet(
#   (stem): ConvNormAct(
#     (conv): Conv2d(3, 24, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn): BatchNormAct2d(
#       24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#       (drop): Identity()
#       (act): SiLU(inplace=True)
#     )
#   )
#   (stages): Sequential(
#     (0): Sequential(
#       (0): BottleneckBlock(
#         (conv1_1x1): ConvNormAct(
#           (conv): Conv2d(24, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): SiLU(inplace=True)
#           )
#         )
#         (conv2_kxk): ConvNormAct(
#           (conv): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48, bias=False)
#           (bn): BatchNormAct2d(
#             48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): SiLU(inplace=True)
#           )
#         )
#         (conv2b_kxk): Identity()
#         (attn): Identity()
#         (conv3_1x1): ConvNormAct(
#           (conv): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (attn_last): Identity()
#         (drop_path): Identity()
#         (act): Identity()
#       )
#     )
#     (1): Sequential(
#       (0): BottleneckBlock(
#         (conv1_1x1): ConvNormAct(
#           (conv): Conv2d(48, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): SiLU(inplace=True)
#           )
#         )
#         (conv2_kxk): ConvNormAct(
#           (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#           (bn): BatchNormAct2d(
#             96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): SiLU(inplace=True)
#           )
#         )
#         (conv2b_kxk): Identity()
#         (attn): Identity()
#         (conv3_1x1): ConvNormAct(
#           (conv): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (attn_last): Identity()
#         (drop_path): Identity()
#         (act): Identity()
#       )
#       (1): BottleneckBlock(
#         (shortcut): Identity()
#         (conv1_1x1): ConvNormAct(
#           (conv): Conv2d(96, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): SiLU(inplace=True)
#           )
#         )
#         (conv2_kxk): ConvNormAct(
#           (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (bn): BatchNormAct2d(
#             192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): SiLU(inplace=True)
#           )
#         )
#         (conv2b_kxk): Identity()
#         (attn): Identity()
#         (conv3_1x1): ConvNormAct(
#           (conv): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (attn_last): Identity()
#         (drop_path): Identity()
#         (act): Identity()
#       )
#     )
#     (2): Sequential(
#       (0): BottleneckBlock(
#         (conv1_1x1): ConvNormAct(
#           (conv): Conv2d(96, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): SiLU(inplace=True)
#           )
#         )
#         (conv2_kxk): ConvNormAct(
#           (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#           (bn): BatchNormAct2d(
#             192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): SiLU(inplace=True)
#           )
#         )
#         (conv2b_kxk): Identity()
#         (attn): Identity()
#         (conv3_1x1): ConvNormAct(
#           (conv): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (attn_last): Identity()
#         (drop_path): Identity()
#         (act): Identity()
#       )
#       (1): MobileVitV2Block(
#         (conv_kxk): ConvNormAct(
#           (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (bn): BatchNormAct2d(
#             192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): SiLU(inplace=True)
#           )
#         )
#         (conv_1x1): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (transformer): Sequential(
#           (0): LinearTransformerBlock(
#             (norm1): GroupNorm1(1, 96, eps=1e-05, affine=True)
#             (attn): LinearSelfAttention(
#               (qkv_proj): Conv2d(96, 193, kernel_size=(1, 1), stride=(1, 1))
#               (attn_drop): Dropout(p=0.0, inplace=False)
#               (out_proj): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1))
#               (out_drop): Dropout(p=0.0, inplace=False)
#             )
#             (drop_path1): DropPath(drop_prob=0.000)
#             (norm2): GroupNorm1(1, 96, eps=1e-05, affine=True)
#             (mlp): ConvMlp(
#               (fc1): Conv2d(96, 192, kernel_size=(1, 1), stride=(1, 1))
#               (norm): Identity()
#               (act): SiLU()
#               (drop): Dropout(p=0.0, inplace=False)
#               (fc2): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1))
#             )
#             (drop_path2): DropPath(drop_prob=0.000)
#           )
#           (1): LinearTransformerBlock(
#             (norm1): GroupNorm1(1, 96, eps=1e-05, affine=True)
#             (attn): LinearSelfAttention(
#               (qkv_proj): Conv2d(96, 193, kernel_size=(1, 1), stride=(1, 1))
#               (attn_drop): Dropout(p=0.0, inplace=False)
#               (out_proj): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1))
#               (out_drop): Dropout(p=0.0, inplace=False)
#             )
#             (drop_path1): DropPath(drop_prob=0.000)
#             (norm2): GroupNorm1(1, 96, eps=1e-05, affine=True)
#             (mlp): ConvMlp(
#               (fc1): Conv2d(96, 192, kernel_size=(1, 1), stride=(1, 1))
#               (norm): Identity()
#               (act): SiLU()
#               (drop): Dropout(p=0.0, inplace=False)
#               (fc2): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1))
#             )
#             (drop_path2): DropPath(drop_prob=0.000)
#           )
#         )
#         (norm): GroupNorm1(1, 96, eps=1e-05, affine=True)
#         (conv_proj): ConvNormAct(
#           (conv): Conv2d(96, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#       )
#     )
#     (3): Sequential(
#       (0): BottleneckBlock(
#         (conv1_1x1): ConvNormAct(
#           (conv): Conv2d(192, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): SiLU(inplace=True)
#           )
#         )
#         (conv2_kxk): ConvNormAct(
#           (conv): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#           (bn): BatchNormAct2d(
#             384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): SiLU(inplace=True)
#           )
#         )
#         (conv2b_kxk): Identity()
#         (attn): Identity()
#         (conv3_1x1): ConvNormAct(
#           (conv): Conv2d(384, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (attn_last): Identity()
#         (drop_path): Identity()
#         (act): Identity()
#       )
#       (1): MobileVitV2Block(
#         (conv_kxk): ConvNormAct(
#           (conv): Conv2d(288, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=288, bias=False)
#           (bn): BatchNormAct2d(
#             288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): SiLU(inplace=True)
#           )
#         )
#         (conv_1x1): Conv2d(288, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (transformer): Sequential(
#           (0): LinearTransformerBlock(
#             (norm1): GroupNorm1(1, 144, eps=1e-05, affine=True)
#             (attn): LinearSelfAttention(
#               (qkv_proj): Conv2d(144, 289, kernel_size=(1, 1), stride=(1, 1))
#               (attn_drop): Dropout(p=0.0, inplace=False)
#               (out_proj): Conv2d(144, 144, kernel_size=(1, 1), stride=(1, 1))
#               (out_drop): Dropout(p=0.0, inplace=False)
#             )
#             (drop_path1): DropPath(drop_prob=0.000)
#             (norm2): GroupNorm1(1, 144, eps=1e-05, affine=True)
#             (mlp): ConvMlp(
#               (fc1): Conv2d(144, 288, kernel_size=(1, 1), stride=(1, 1))
#               (norm): Identity()
#               (act): SiLU()
#               (drop): Dropout(p=0.0, inplace=False)
#               (fc2): Conv2d(288, 144, kernel_size=(1, 1), stride=(1, 1))
#             )
#             (drop_path2): DropPath(drop_prob=0.000)
#           )
#           (1): LinearTransformerBlock(
#             (norm1): GroupNorm1(1, 144, eps=1e-05, affine=True)
#             (attn): LinearSelfAttention(
#               (qkv_proj): Conv2d(144, 289, kernel_size=(1, 1), stride=(1, 1))
#               (attn_drop): Dropout(p=0.0, inplace=False)
#               (out_proj): Conv2d(144, 144, kernel_size=(1, 1), stride=(1, 1))
#               (out_drop): Dropout(p=0.0, inplace=False)
#             )
#             (drop_path1): DropPath(drop_prob=0.000)
#             (norm2): GroupNorm1(1, 144, eps=1e-05, affine=True)
#             (mlp): ConvMlp(
#               (fc1): Conv2d(144, 288, kernel_size=(1, 1), stride=(1, 1))
#               (norm): Identity()
#               (act): SiLU()
#               (drop): Dropout(p=0.0, inplace=False)
#               (fc2): Conv2d(288, 144, kernel_size=(1, 1), stride=(1, 1))
#             )
#             (drop_path2): DropPath(drop_prob=0.000)
#           )
#           (2): LinearTransformerBlock(
#             (norm1): GroupNorm1(1, 144, eps=1e-05, affine=True)
#             (attn): LinearSelfAttention(
#               (qkv_proj): Conv2d(144, 289, kernel_size=(1, 1), stride=(1, 1))
#               (attn_drop): Dropout(p=0.0, inplace=False)
#               (out_proj): Conv2d(144, 144, kernel_size=(1, 1), stride=(1, 1))
#               (out_drop): Dropout(p=0.0, inplace=False)
#             )
#             (drop_path1): DropPath(drop_prob=0.000)
#             (norm2): GroupNorm1(1, 144, eps=1e-05, affine=True)
#             (mlp): ConvMlp(
#               (fc1): Conv2d(144, 288, kernel_size=(1, 1), stride=(1, 1))
#               (norm): Identity()
#               (act): SiLU()
#               (drop): Dropout(p=0.0, inplace=False)
#               (fc2): Conv2d(288, 144, kernel_size=(1, 1), stride=(1, 1))
#             )
#             (drop_path2): DropPath(drop_prob=0.000)
#           )
#           (3): LinearTransformerBlock(
#             (norm1): GroupNorm1(1, 144, eps=1e-05, affine=True)
#             (attn): LinearSelfAttention(
#               (qkv_proj): Conv2d(144, 289, kernel_size=(1, 1), stride=(1, 1))
#               (attn_drop): Dropout(p=0.0, inplace=False)
#               (out_proj): Conv2d(144, 144, kernel_size=(1, 1), stride=(1, 1))
#               (out_drop): Dropout(p=0.0, inplace=False)
#             )
#             (drop_path1): DropPath(drop_prob=0.000)
#             (norm2): GroupNorm1(1, 144, eps=1e-05, affine=True)
#             (mlp): ConvMlp(
#               (fc1): Conv2d(144, 288, kernel_size=(1, 1), stride=(1, 1))
#               (norm): Identity()
#               (act): SiLU()
#               (drop): Dropout(p=0.0, inplace=False)
#               (fc2): Conv2d(288, 144, kernel_size=(1, 1), stride=(1, 1))
#             )
#             (drop_path2): DropPath(drop_prob=0.000)
#           )
#         )
#         (norm): GroupNorm1(1, 144, eps=1e-05, affine=True)
#         (conv_proj): ConvNormAct(
#           (conv): Conv2d(144, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#       )
#     )
#     (4): Sequential(
#       (0): BottleneckBlock(
#         (conv1_1x1): ConvNormAct(
#           (conv): Conv2d(288, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): SiLU(inplace=True)
#           )
#         )
#         (conv2_kxk): ConvNormAct(
#           (conv): Conv2d(576, 576, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=576, bias=False)
#           (bn): BatchNormAct2d(
#             576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): SiLU(inplace=True)
#           )
#         )
#         (conv2b_kxk): Identity()
#         (attn): Identity()
#         (conv3_1x1): ConvNormAct(
#           (conv): Conv2d(576, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#         (attn_last): Identity()
#         (drop_path): Identity()
#         (act): Identity()
#       )
#       (1): MobileVitV2Block(
#         (conv_kxk): ConvNormAct(
#           (conv): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (bn): BatchNormAct2d(
#             384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): SiLU(inplace=True)
#           )
#         )
#         (conv_1x1): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (transformer): Sequential(
#           (0): LinearTransformerBlock(
#             (norm1): GroupNorm1(1, 192, eps=1e-05, affine=True)
#             (attn): LinearSelfAttention(
#               (qkv_proj): Conv2d(192, 385, kernel_size=(1, 1), stride=(1, 1))
#               (attn_drop): Dropout(p=0.0, inplace=False)
#               (out_proj): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1))
#               (out_drop): Dropout(p=0.0, inplace=False)
#             )
#             (drop_path1): DropPath(drop_prob=0.000)
#             (norm2): GroupNorm1(1, 192, eps=1e-05, affine=True)
#             (mlp): ConvMlp(
#               (fc1): Conv2d(192, 384, kernel_size=(1, 1), stride=(1, 1))
#               (norm): Identity()
#               (act): SiLU()
#               (drop): Dropout(p=0.0, inplace=False)
#               (fc2): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1))
#             )
#             (drop_path2): DropPath(drop_prob=0.000)
#           )
#           (1): LinearTransformerBlock(
#             (norm1): GroupNorm1(1, 192, eps=1e-05, affine=True)
#             (attn): LinearSelfAttention(
#               (qkv_proj): Conv2d(192, 385, kernel_size=(1, 1), stride=(1, 1))
#               (attn_drop): Dropout(p=0.0, inplace=False)
#               (out_proj): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1))
#               (out_drop): Dropout(p=0.0, inplace=False)
#             )
#             (drop_path1): DropPath(drop_prob=0.000)
#             (norm2): GroupNorm1(1, 192, eps=1e-05, affine=True)
#             (mlp): ConvMlp(
#               (fc1): Conv2d(192, 384, kernel_size=(1, 1), stride=(1, 1))
#               (norm): Identity()
#               (act): SiLU()
#               (drop): Dropout(p=0.0, inplace=False)
#               (fc2): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1))
#             )
#             (drop_path2): DropPath(drop_prob=0.000)
#           )
#           (2): LinearTransformerBlock(
#             (norm1): GroupNorm1(1, 192, eps=1e-05, affine=True)
#             (attn): LinearSelfAttention(
#               (qkv_proj): Conv2d(192, 385, kernel_size=(1, 1), stride=(1, 1))
#               (attn_drop): Dropout(p=0.0, inplace=False)
#               (out_proj): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1))
#               (out_drop): Dropout(p=0.0, inplace=False)
#             )
#             (drop_path1): DropPath(drop_prob=0.000)
#             (norm2): GroupNorm1(1, 192, eps=1e-05, affine=True)
#             (mlp): ConvMlp(
#               (fc1): Conv2d(192, 384, kernel_size=(1, 1), stride=(1, 1))
#               (norm): Identity()
#               (act): SiLU()
#               (drop): Dropout(p=0.0, inplace=False)
#               (fc2): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1))
#             )
#             (drop_path2): DropPath(drop_prob=0.000)
#           )
#         )
#         (norm): GroupNorm1(1, 192, eps=1e-05, affine=True)
#         (conv_proj): ConvNormAct(
#           (conv): Conv2d(192, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNormAct2d(
#             384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): Identity()
#           )
#         )
#       )
#     )
#   )
#   (final_conv): Identity()
#   (head): ClassifierHead(
#     (global_pool): SelectAdaptivePool2d (pool_type=avg, flatten=Flatten(start_dim=1, end_dim=-1))
#     (drop): Dropout(p=0.0, inplace=False)
#     (fc): Linear(in_features=384, out_features=24, bias=True)
#     (flatten): Identity()
#   )
# )

# %% [markdown]
# # Compile  model

# %%
# Define the optimizer and loss function
optimizer = optim.Adam(model.parameters(), lr=1e-5)
criterion = torch.nn.CrossEntropyLoss()

# Define the best accuracy
best_accuracy = 0
epsilon = 1e-5
epochs = 100

# %% [markdown]
# # train the head of the network

# %%
train_losses = []
train_accuracies = []
val_losses = []
val_accuracies = []

# Training loop
print('Start training...')
for epoch in range(epochs):
    model.train()
    train_loss = 0.0
    correct = 0
    total = 0
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    avg_train_loss = train_loss / len(train_loader)
    train_accuracy = 100 * correct / total
    train_losses.append(avg_train_loss)
    train_accuracies.append(train_accuracy)

    # Validation loop
    model.eval()
    val_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    avg_val_loss = val_loss / len(val_loader)
    val_accuracy = 100 * correct / total
    val_losses.append(avg_val_loss)
    val_accuracies.append(val_accuracy)

    print(f'Epoch {epoch+1}, Train Loss: {avg_train_loss:.4f}, Train Accuracy: {train_accuracy:.2f}%, Val Loss: {avg_val_loss:.4f}, Val Accuracy: {val_accuracy:.2f}%')

    if val_accuracy > best_accuracy:
        best_accuracy = val_accuracy
        torch.save(model.state_dict(), 'models/best.pt')

# Save the last model
torch.save(model.state_dict(), 'models/last.pt')
# Out:
# Start training...
# Epoch 1, Train Loss: 2.9892, Train Accuracy: 25.16%, Val Loss: 2.7367, Val Accuracy: 49.50%
# Epoch 2, Train Loss: 2.4151, Train Accuracy: 55.85%, Val Loss: 2.0203, Val Accuracy: 63.77%
# Epoch 3, Train Loss: 1.7451, Train Accuracy: 65.49%, Val Loss: 1.3968, Val Accuracy: 71.30%
# Epoch 4, Train Loss: 1.2272, Train Accuracy: 74.21%, Val Loss: 0.9470, Val Accuracy: 78.74%
# Epoch 5, Train Loss: 0.8423, Train Accuracy: 81.69%, Val Loss: 0.6263, Val Accuracy: 85.33%
# Epoch 6, Train Loss: 0.5718, Train Accuracy: 86.25%, Val Loss: 0.4230, Val Accuracy: 88.00%
# Epoch 7, Train Loss: 0.4043, Train Accuracy: 88.88%, Val Loss: 0.3129, Val Accuracy: 89.43%
# Epoch 8, Train Loss: 0.3051, Train Accuracy: 90.67%, Val Loss: 0.2367, Val Accuracy: 92.50%
# Epoch 9, Train Loss: 0.2331, Train Accuracy: 93.71%, Val Loss: 0.1736, Val Accuracy: 95.44%
# Epoch 10, Train Loss: 0.1632, Train Accuracy: 96.30%, Val Loss: 0.1032, Val Accuracy: 97.84%
# Epoch 11, Train Loss: 0.1042, Train Accuracy: 97.97%, Val Loss: 0.0668, Val Accuracy: 98.69%
# Epoch 12, Train Loss: 0.0679, Train Accuracy: 98.69%, Val Loss: 0.0341, Val Accuracy: 99.48%
# Epoch 13, Train Loss: 0.0454, Train Accuracy: 99.16%, Val Loss: 0.0221, Val Accuracy: 99.70%
# Epoch 14, Train Loss: 0.0326, Train Accuracy: 99.31%, Val Loss: 0.0171, Val Accuracy: 99.70%
# Epoch 15, Train Loss: 0.0240, Train Accuracy: 99.53%, Val Loss: 0.0127, Val Accuracy: 99.76%
# Epoch 16, Train Loss: 0.0201, Train Accuracy: 99.54%, Val Loss: 0.0110, Val Accuracy: 99.73%
# Epoch 17, Train Loss: 0.0155, Train Accuracy: 99.62%, Val Loss: 0.0074, Val Accuracy: 99.76%
# Epoch 18, Train Loss: 0.0141, Train Accuracy: 99.59%, Val Loss: 0.0072, Val Accuracy: 99.82%
# Epoch 19, Train Loss: 0.0126, Train Accuracy: 99.66%, Val Loss: 0.0066, Val Accuracy: 99.76%
# Epoch 20, Train Loss: 0.0107, Train Accuracy: 99.65%, Val Loss: 0.0054, Val Accuracy: 99.82%
# Epoch 21, Train Loss: 0.0096, Train Accuracy: 99.67%, Val Loss: 0.0064, Val Accuracy: 99.70%
# Epoch 22, Train Loss: 0.0080, Train Accuracy: 99.71%, Val Loss: 0.0056, Val Accuracy: 99.73%
# Epoch 23, Train Loss: 0.0072, Train Accuracy: 99.73%, Val Loss: 0.0042, Val Accuracy: 99.79%
# Epoch 24, Train Loss: 0.0070, Train Accuracy: 99.74%, Val Loss: 0.0058, Val Accuracy: 99.73%
# Epoch 25, Train Loss: 0.0061, Train Accuracy: 99.75%, Val Loss: 0.0044, Val Accuracy: 99.73%
# Epoch 26, Train Loss: 0.0066, Train Accuracy: 99.75%, Val Loss: 0.0048, Val Accuracy: 99.76%
# Epoch 27, Train Loss: 0.0059, Train Accuracy: 99.76%, Val Loss: 0.0051, Val Accuracy: 99.70%
# Epoch 28, Train Loss: 0.0056, Train Accuracy: 99.78%, Val Loss: 0.0041, Val Accuracy: 99.76%
# Epoch 29, Train Loss: 0.0061, Train Accuracy: 99.72%, Val Loss: 0.0041, Val Accuracy: 99.73%
# Epoch 30, Train Loss: 0.0053, Train Accuracy: 99.76%, Val Loss: 0.0040, Val Accuracy: 99.70%
# Epoch 31, Train Loss: 0.0053, Train Accuracy: 99.76%, Val Loss: 0.0046, Val Accuracy: 99.70%
# Epoch 32, Train Loss: 0.0050, Train Accuracy: 99.75%, Val Loss: 0.0039, Val Accuracy: 99.76%
# Epoch 33, Train Loss: 0.0052, Train Accuracy: 99.72%, Val Loss: 0.0040, Val Accuracy: 99.76%
# Epoch 34, Train Loss: 0.0046, Train Accuracy: 99.77%, Val Loss: 0.0041, Val Accuracy: 99.70%
# Epoch 35, Train Loss: 0.0048, Train Accuracy: 99.76%, Val Loss: 0.0046, Val Accuracy: 99.70%
# Epoch 36, Train Loss: 0.0047, Train Accuracy: 99.76%, Val Loss: 0.0039, Val Accuracy: 99.70%
# Epoch 37, Train Loss: 0.0045, Train Accuracy: 99.77%, Val Loss: 0.0047, Val Accuracy: 99.70%
# Epoch 38, Train Loss: 0.0041, Train Accuracy: 99.78%, Val Loss: 0.0036, Val Accuracy: 99.79%
# Epoch 39, Train Loss: 0.0046, Train Accuracy: 99.74%, Val Loss: 0.0034, Val Accuracy: 99.79%
# Epoch 40, Train Loss: 0.0038, Train Accuracy: 99.81%, Val Loss: 0.0038, Val Accuracy: 99.73%
# Epoch 41, Train Loss: 0.0038, Train Accuracy: 99.79%, Val Loss: 0.0037, Val Accuracy: 99.70%
# Epoch 42, Train Loss: 0.0040, Train Accuracy: 99.77%, Val Loss: 0.0032, Val Accuracy: 99.85%
# Epoch 43, Train Loss: 0.0040, Train Accuracy: 99.75%, Val Loss: 0.0036, Val Accuracy: 99.67%
# Epoch 44, Train Loss: 0.0042, Train Accuracy: 99.74%, Val Loss: 0.0035, Val Accuracy: 99.73%
# Epoch 45, Train Loss: 0.0039, Train Accuracy: 99.76%, Val Loss: 0.0036, Val Accuracy: 99.70%
# Epoch 46, Train Loss: 0.0037, Train Accuracy: 99.80%, Val Loss: 0.0032, Val Accuracy: 99.82%
# Epoch 47, Train Loss: 0.0042, Train Accuracy: 99.72%, Val Loss: 0.0032, Val Accuracy: 99.76%
# Epoch 48, Train Loss: 0.0043, Train Accuracy: 99.72%, Val Loss: 0.0035, Val Accuracy: 99.70%
# Epoch 49, Train Loss: 0.0039, Train Accuracy: 99.77%, Val Loss: 0.0031, Val Accuracy: 99.85%
# Epoch 50, Train Loss: 0.0038, Train Accuracy: 99.75%, Val Loss: 0.0033, Val Accuracy: 99.76%
# Epoch 51, Train Loss: 0.0038, Train Accuracy: 99.78%, Val Loss: 0.0035, Val Accuracy: 99.64%
# Epoch 52, Train Loss: 0.0040, Train Accuracy: 99.74%, Val Loss: 0.0034, Val Accuracy: 99.73%
# Epoch 53, Train Loss: 0.0038, Train Accuracy: 99.76%, Val Loss: 0.0035, Val Accuracy: 99.73%
# Epoch 54, Train Loss: 0.0037, Train Accuracy: 99.78%, Val Loss: 0.0031, Val Accuracy: 99.82%
# Epoch 55, Train Loss: 0.0037, Train Accuracy: 99.78%, Val Loss: 0.0033, Val Accuracy: 99.73%
# Epoch 56, Train Loss: 0.0037, Train Accuracy: 99.79%, Val Loss: 0.0037, Val Accuracy: 99.70%
# Epoch 57, Train Loss: 0.0038, Train Accuracy: 99.75%, Val Loss: 0.0032, Val Accuracy: 99.76%
# Epoch 58, Train Loss: 0.0038, Train Accuracy: 99.75%, Val Loss: 0.0035, Val Accuracy: 99.73%
# Epoch 59, Train Loss: 0.0036, Train Accuracy: 99.75%, Val Loss: 0.0037, Val Accuracy: 99.70%
# Epoch 60, Train Loss: 0.0037, Train Accuracy: 99.73%, Val Loss: 0.0038, Val Accuracy: 99.70%
# Epoch 61, Train Loss: 0.0038, Train Accuracy: 99.75%, Val Loss: 0.0036, Val Accuracy: 99.70%
# Epoch 62, Train Loss: 0.0039, Train Accuracy: 99.76%, Val Loss: 0.0032, Val Accuracy: 99.79%
# Epoch 63, Train Loss: 0.0033, Train Accuracy: 99.78%, Val Loss: 0.0035, Val Accuracy: 99.73%
# Epoch 64, Train Loss: 0.0035, Train Accuracy: 99.77%, Val Loss: 0.0034, Val Accuracy: 99.70%
# Epoch 65, Train Loss: 0.0034, Train Accuracy: 99.77%, Val Loss: 0.0036, Val Accuracy: 99.70%
# Epoch 66, Train Loss: 0.0035, Train Accuracy: 99.78%, Val Loss: 0.0033, Val Accuracy: 99.73%
# Epoch 67, Train Loss: 0.0035, Train Accuracy: 99.78%, Val Loss: 0.0034, Val Accuracy: 99.67%
# Epoch 68, Train Loss: 0.0040, Train Accuracy: 99.78%, Val Loss: 0.0036, Val Accuracy: 99.70%
# Epoch 69, Train Loss: 0.0036, Train Accuracy: 99.73%, Val Loss: 0.0033, Val Accuracy: 99.70%
# Epoch 70, Train Loss: 0.0033, Train Accuracy: 99.81%, Val Loss: 0.0039, Val Accuracy: 99.70%
# Epoch 71, Train Loss: 0.0037, Train Accuracy: 99.77%, Val Loss: 0.0031, Val Accuracy: 99.82%
# Epoch 72, Train Loss: 0.0034, Train Accuracy: 99.77%, Val Loss: 0.0039, Val Accuracy: 99.70%
# Epoch 73, Train Loss: 0.0034, Train Accuracy: 99.75%, Val Loss: 0.0033, Val Accuracy: 99.73%
# Epoch 74, Train Loss: 0.0036, Train Accuracy: 99.75%, Val Loss: 0.0034, Val Accuracy: 99.70%
# Epoch 75, Train Loss: 0.0037, Train Accuracy: 99.75%, Val Loss: 0.0032, Val Accuracy: 99.79%
# Epoch 76, Train Loss: 0.0034, Train Accuracy: 99.75%, Val Loss: 0.0032, Val Accuracy: 99.73%
# Epoch 77, Train Loss: 0.0034, Train Accuracy: 99.78%, Val Loss: 0.0031, Val Accuracy: 99.82%
# Epoch 78, Train Loss: 0.0036, Train Accuracy: 99.72%, Val Loss: 0.0035, Val Accuracy: 99.67%
# Epoch 79, Train Loss: 0.0033, Train Accuracy: 99.77%, Val Loss: 0.0033, Val Accuracy: 99.70%
# Epoch 80, Train Loss: 0.0035, Train Accuracy: 99.75%, Val Loss: 0.0039, Val Accuracy: 99.70%
# Epoch 81, Train Loss: 0.0035, Train Accuracy: 99.77%, Val Loss: 0.0033, Val Accuracy: 99.70%
# Epoch 82, Train Loss: 0.0034, Train Accuracy: 99.79%, Val Loss: 0.0034, Val Accuracy: 99.70%
# Epoch 83, Train Loss: 0.0038, Train Accuracy: 99.74%, Val Loss: 0.0032, Val Accuracy: 99.79%
# Epoch 84, Train Loss: 0.0035, Train Accuracy: 99.76%, Val Loss: 0.0031, Val Accuracy: 99.82%
# Epoch 85, Train Loss: 0.0034, Train Accuracy: 99.78%, Val Loss: 0.0031, Val Accuracy: 99.82%
# Epoch 86, Train Loss: 0.0033, Train Accuracy: 99.78%, Val Loss: 0.0032, Val Accuracy: 99.79%
# Epoch 87, Train Loss: 0.0034, Train Accuracy: 99.79%, Val Loss: 0.0032, Val Accuracy: 99.73%
# Epoch 88, Train Loss: 0.0036, Train Accuracy: 99.77%, Val Loss: 0.0031, Val Accuracy: 99.82%
# Epoch 89, Train Loss: 0.0033, Train Accuracy: 99.77%, Val Loss: 0.0032, Val Accuracy: 99.79%
# Epoch 90, Train Loss: 0.0037, Train Accuracy: 99.76%, Val Loss: 0.0033, Val Accuracy: 99.73%
# Epoch 91, Train Loss: 0.0035, Train Accuracy: 99.76%, Val Loss: 0.0033, Val Accuracy: 99.67%
# Epoch 92, Train Loss: 0.0032, Train Accuracy: 99.79%, Val Loss: 0.0035, Val Accuracy: 99.70%
# Epoch 93, Train Loss: 0.0033, Train Accuracy: 99.77%, Val Loss: 0.0035, Val Accuracy: 99.70%
# Epoch 94, Train Loss: 0.0036, Train Accuracy: 99.76%, Val Loss: 0.0032, Val Accuracy: 99.79%
# Epoch 95, Train Loss: 0.0034, Train Accuracy: 99.77%, Val Loss: 0.0031, Val Accuracy: 99.76%
# Epoch 96, Train Loss: 0.0034, Train Accuracy: 99.75%, Val Loss: 0.0034, Val Accuracy: 99.73%
# Epoch 97, Train Loss: 0.0035, Train Accuracy: 99.76%, Val Loss: 0.0031, Val Accuracy: 99.82%
# Epoch 98, Train Loss: 0.0033, Train Accuracy: 99.77%, Val Loss: 0.0035, Val Accuracy: 99.73%
# Epoch 99, Train Loss: 0.0033, Train Accuracy: 99.79%, Val Loss: 0.0033, Val Accuracy: 99.73%
# Epoch 100, Train Loss: 0.0035, Train Accuracy: 99.77%, Val Loss: 0.0037, Val Accuracy: 99.70%

# %% [markdown]
# # accuracy & loss curves

# %%
# Generating predictions for the test dataset
test_dataset = datasets.ImageFolder(root='../../main_dataset/test', transform=transform)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)
model.eval()
all_preds = []
all_labels = []
with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        all_preds.extend(predicted.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

# Compute the confusion matrix
cm = confusion_matrix(all_labels, all_preds)

# %%
# Plotting training and validation loss
plt.figure(figsize=(10, 5))
plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plotting training and validation accuracy
plt.figure(figsize=(10, 5))
plt.plot(train_accuracies, label='Training Accuracy')
plt.plot(val_accuracies, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Displaying the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.show()
